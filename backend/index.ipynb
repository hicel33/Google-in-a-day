# %% [markdown]
# # backend/index.ipynb (scaffold)
#
# Index store notebook: define `IndexEntry` dataclass and the event-loop-only in-memory `index` dict.

# %%
from __future__ import annotations

# TODO:
# - define `IndexEntry` dataclass with url/origin_url/depth/title/body_text/crawled_at
# - define helpers to add/update entries in event-loop only context
# - define type hints for index: dict[str, IndexEntry]

# from dataclasses import dataclass

# @dataclass
# class IndexEntry:
#     url: str
#     origin_url: str
#     depth: int
#     title: str
#     body_text: str
#     crawled_at: float
