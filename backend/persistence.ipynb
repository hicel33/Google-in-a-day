# %% [markdown]
# # backend/persistence.ipynb (scaffold)
#
# Persistence notebook: implement JSON snapshot save/load for `visited`, `index`, pending queue items, and crawl config (bonus).

# %%
from __future__ import annotations

# TODO:
# - define snapshot schema
# - implement save_snapshot(state, path)
# - implement load_snapshot(path) -> state
# - integrate with SIGINT and POST /pause|/resume

# def save_snapshot(...):
#     ...
