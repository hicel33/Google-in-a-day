# %% [markdown]
# # backend/metrics.ipynb (scaffold)
#
# Metrics notebook: define `CrawlMetrics` dataclass and update helpers for crawled/dropped/worker utilization/back-pressure.

# %%
from __future__ import annotations

# TODO:
# - define CrawlMetrics dataclass
# - helper methods to update status and compute back_pressure indicator
# - ensure updates happen in the event loop only

# from dataclasses import dataclass
# @dataclass
# class CrawlMetrics:
#     ...
